# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.axis([-5,5,-5,5])
plt.axis('square')
plt.grid()

x = np.array([-5,5])

# y = 0.7x + -2
y = (0.7*x) + (-2)
plt.plot(x,y,'k')

# y = -1.25x + 0.75
y = (-1.25*x) + (0.75)
plt.plot(x,y,'k')
